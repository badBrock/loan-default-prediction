# %%
# Cell 1
import sys
sys.path.append('..')

import pandas as pd
from src.models.train import load_features, compute_scale_pos_weight
from src.models.evaluate import compare_models
from src.features.build_features import get_feature_cols

# Cell 2
train = load_features()
feature_cols = get_feature_cols(train)
spw = compute_scale_pos_weight(train['TARGET'])
print('scale_pos_weight:', round(spw, 2))

# Cell 3
results = compare_models(train, feature_cols, spw)
results
